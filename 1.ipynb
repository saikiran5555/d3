# %% [markdown]
# Eigenvalues and eigenvectors are concepts from linear algebra that are closely related and play a crucial role in various mathematical and computational applications, including the Eigen-Decomposition approach.
#
# Eigenvalues: Eigenvalues are scalar values that represent the scaling factor by which an eigenvector is stretched or shrunk when a linear transformation is applied to it. In other words, they indicate how much variance is captured in a particular direction (eigenvector) of a matrix or transformation. Eigenvalues are typically denoted by the symbol λ (lambda).
#
# Eigenvectors: Eigenvectors are non-zero vectors that remain in the same direction after a linear transformation is applied to them, albeit possibly scaled by an eigenvalue. In the context of matrices, an eigenvector of a square matrix A is a vector v such that when A is multiplied by v, the result is a scalar multiple of v, i.e., Av = λv, where λ is the eigenvalue associated with v.
#
# Eigen-Decomposition: Eigen-Decomposition is a method used to decompose a square matrix into its constituent eigenvectors and eigenvalues. For a matrix A, the eigen-decomposition is represented as A = QΛQ^(-1), where Q is a matrix whose columns are the eigenvectors of A, Λ is a diagonal matrix containing the corresponding eigenvalues, and Q^(-1) is the inverse of Q.
#
# Now, let's illustrate these concepts with an example:
#
# Consider the following 2x2 matrix A:
#
# �
# =
# [
# 2
# 1
# 1
# 3
# ]
# A=[
# 2
# 1
# ​
#
# 1
# 3
# ​
#  ]
#
# To find the eigenvalues (λ) and eigenvectors (v) of A, we solve the eigenvalue equation Av = λv:
#
# First, we compute the characteristic polynomial of A:
# ∣
# �
# −
# �
# �
# ∣
# =
# ∣
# 2
# −
# �
# 1
# 1
# 3
# −
# �
# ∣
# =
# (
# 2
# −
# �
# )
# (
# 3
# −
# �
# )
# −
# 1
# ×
# 1
# =
# �
# 2
# −
# 5
# �
# +
# 5
# ∣A−λI∣=
# ∣
# ∣
# ​
#
# 2−λ
# 1
# ​
#
# 1
# 3−λ
# ​
#
# ∣
# ∣
# ​
#  =(2−λ)(3−λ)−1×1=λ
# 2
#  −5λ+5
#
# Next, we solve for the eigenvalues by setting the characteristic polynomial equal to zero and solving for λ:
# �
# 2
# −
# 5
# �
# +
# 5
# =
# 0
# λ
# 2
#  −5λ+5=0
#
# By solving the quadratic equation, we find two eigenvalues: λ₁ ≈ 1.1716 and λ₂ ≈ 3.8284.
#
# Once we have the eigenvalues, we can find the corresponding eigenvectors by substituting each eigenvalue back into the eigenvalue equation and solving for v:
# For λ₁ ≈ 1.1716:
# �
# −
# �
# 1
# �
# =
# [
# 2
# −
# 1.1716
# 1
# 1
# 3
# −
# 1.1716
# ]
# =
# [
# 0.8284
# 1
# 1
# 1.8284
# ]
# A−λ
# 1
# ​
#  I=[
# 2−1.1716
# 1
# ​
#
# 1
# 3−1.1716
# ​
#  ]=[
# 0.8284
# 1
# ​
#
# 1
# 1.8284
# ​
#  ]
#
# Solving for Av = λv, we find the eigenvector corresponding to λ₁ as v₁ ≈ [0.5253, 0.8507].
#
# Similarly, for λ₂ ≈ 3.8284, we find the eigenvector v₂ ≈ [-0.8507, 0.5253].
#
# Finally, the eigen-decomposition of matrix A is given by:
# �
# =
# �
# Λ
# �
# (
# −
# 1
# )
# A=QΛQ
# (
#  −1)
#
# Where Q is the matrix whose columns are the eigenvectors v₁ and v₂, Λ is the diagonal matrix containing the eigenvalues λ₁ and λ₂, and Q^(-1) is the inverse of Q.
#
# �
# =
# [
# 0.5253
# −
# 0.8507
# 0.8507
# 0.5253
# ]
# Q=[
# 0.5253
# 0.8507
# ​
#
# −0.8507
# 0.5253
# ​
#  ]
#
# Λ
# =
# [
# 1.1716
# 0
# 0
# 3.8284
# ]
# Λ=[
# 1.1716
# 0
# ​
#
# 0
# 3.8284
# ​
#  ]
#
# �
# (
# −
# 1
# )
# =
# 1
# �
# �
# �
# (
# �
# )
# [
# 0.5253
# 0.8507
# −
# 0.8507
# 0.5253
# ]
# Q
# (
#  −1)=
# det(Q)
# 1
# ​
#  [
# 0.5253
# −0.8507
# ​
#
# 0.8507
# 0.5253
# ​
#  ]
#
# �
# (
# −
# 1
# )
# =
# [
# 0.5253
# 0.8507
# −
# 0.8507
# 0.5253
# ]
# Q
# (
#  −1)=[
# 0.5253
# −0.8507
# ​
#
# 0.8507
# 0.5253
# ​
#  ]
#
# �
# =
# [
# 0.5253
# −
# 0.8507
# 0.8507
# 0.5253
# ]
# [
# 1.1716
# 0
# 0
# 3.8284
# ]
# [
# 0.5253
# 0.8507
# −
# 0.8507
# 0.5253
# ]
# A=[
# 0.5253
# 0.8507
# ​
#
# −0.8507
# 0.5253
# ​
#  ][
# 1.1716
# 0
# ​
#
# 0
# 3.8284
# ​
#  ][
# 0.5253
# −0.8507
# ​
#
# 0.8507
# 0.5253
# ​
#  ]
#
# �
# ≈
# [
# 2
# 1
# 1
# 3
# ]
# A≈[
# 2
# 1
# ​
#
# 1
# 3
# ​
#  ]
#
# This example demonstrates how eigenvalues and eigenvectors are computed and used in the eigen-decomposition approach to decompose a matrix into its constituent parts. Eigenvalues represent the scaling factors, while eigenvectors represent the directions of maximum variance in the data. Eigen-decomposition is a powerful tool used in various applications, including data analysis, signal processing, and quantum mechanics.
